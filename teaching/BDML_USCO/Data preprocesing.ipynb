# %% [markdown]
# # **Data preprocessing and features creation**

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# - For this class we are going to use Properati´s Open Data for properties in Bogotá. You can get acces to this data [here](https://www.properati.com.co/data).

# %%
df = pd.read_csv('co_properties.csv.gz', compression='gzip', header=0,    sep=',', quotechar='"', error_bad_lines=False)

# %%
df.shape[1]
# Out:
# 25

# %%
df.columns
# Out:
# Index(['id', 'ad_type', 'start_date', 'end_date', 'created_on', 'lat', 'lon',
#        'l1', 'l2', 'l3', 'l4', 'l5', 'l6', 'rooms', 'bedrooms', 'bathrooms',
#        'surface_total', 'surface_covered', 'price', 'currency', 'price_period',
#        'title', 'description', 'property_type', 'operation_type'],
#       dtype='object')

# %% [markdown]
# - First, we are going to make a data frame that contains only data from properties in Bogotá.

# %%
df
# Out:
#                               id    ad_type  start_date    end_date  \
# 0       TwS+KTQ1LigejcnVcR8wQA==  Propiedad  2020-10-10  2021-01-09
# 1       exe9suxTarpGHR3XC7E5DQ==  Propiedad  2020-10-10  2020-10-30
# 2       O7bfpWBSwJOh+1j2tNIT7Q==  Propiedad  2020-10-10  2020-11-13
# 3       9aGw3lg9cblCh3D/BookWg==  Propiedad  2020-10-10  2020-11-12
# 4       6rglCGhfwQeesD0zNLy/pw==  Propiedad  2020-10-10  2021-02-12
# ...                          ...        ...         ...         ...
# 999995  5GJ0XVQ7+rn95XRI3tSB+Q==  Propiedad  2020-07-23  2020-08-01
# 999996  VEkggjq5UPdxX5osneJGHQ==  Propiedad  2020-07-23  2021-08-09
# 999997  YXGr5K1neic8fuwfTPpYBQ==  Propiedad  2020-07-23  2020-08-01
# 999998  /qBt6Y8IqDeiKi3DC6XBLw==  Propiedad  2020-07-23  2021-03-16
# 999999  TFP5g2GWQpvKVMhIYM1n2Q==  Propiedad  2020-07-23  2020-08-21
#
#         created_on        lat        lon        l1               l2  \
# 0       2020-10-10   6.274566 -75.642269  Colombia        Antioquia
# 1       2020-10-10   4.592129 -74.123863  Colombia     Cundinamarca
# 2       2020-10-10  10.985000 -74.795000  Colombia        Atlántico
# 3       2020-10-10   3.366000 -76.541000  Colombia  Valle del Cauca
# 4       2020-10-10   6.229068 -75.536363  Colombia        Antioquia
# ...            ...        ...        ...       ...              ...
# 999995  2020-07-23   6.198000 -75.565000  Colombia        Antioquia
# 999996  2020-07-23   4.600097 -74.075562  Colombia     Cundinamarca
# 999997  2020-07-23   3.420000 -76.546000  Colombia  Valle del Cauca
# 999998  2020-07-23        NaN        NaN  Colombia     Cundinamarca
# 999999  2020-07-23  11.000000 -74.807000  Colombia        Atlántico
#
#                   l3  ... bathrooms surface_total surface_covered  \
# 0           Medellín  ...       NaN           NaN             NaN
# 1         Bogotá D.C  ...       NaN           NaN             NaN
# 2       Barranquilla  ...       NaN         250.0           250.0
# 3               Cali  ...       NaN          77.0            77.0
# 4           Medellín  ...       NaN           NaN             NaN
# ...              ...  ...       ...           ...             ...
# 999995      Medellín  ...       2.0         200.0           200.0
# 999996    Bogotá D.C  ...       2.0           NaN             NaN
# 999997          Cali  ...       3.0           NaN           400.0
# 999998    Bogotá D.C  ...       3.0         102.0           254.0
# 999999  Barranquilla  ...       3.0         600.0           600.0
#
#               price  currency  price_period  \
# 0       150000000.0       COP           NaN
# 1        11000000.0       COP           NaN
# 2       900000000.0       COP           NaN
# 3       550000000.0       COP           NaN
# 4       125000000.0       COP           NaN
# ...             ...       ...           ...
# 999995   12500000.0       COP           NaN
# 999996    2800000.0       COP           NaN
# 999997    9500000.0       COP           NaN
# 999998   10000000.0       COP           NaN
# 999999   17000000.0       COP           NaN
#
#                                                     title  \
# 0       MARAVILLOSO LOTE EN VENTA _ SECTOR SAN CRISTOB...
# 1                Local comercial esquinero - Centro Mayor
# 2       Bodega En Arriendo/venta En Barranquilla Bosto...
# 3       Consultorio En Venta En Cali Ciudad Jardn Cod....
# 4          Venta Apartamento en Buenos Aires Bosque Verde
# ...                                                   ...
# 999995  Local En Arriendo En Medellin El Poblado Cod. ...
# 999996            LOCAL EN ARRIENDO, BOGOTA-LA CANDELARIA
# 999997  Local En Arriendo En Cali Urbanizacin Tequenda...
# 999998  Local En Arriendo En Bogota Prado Veraniego Co...
# 999999  Local En Arriendo En Barranquilla Alto Prado C...
#
#                                               description    property_type  \
# 0       COD.20071 Maravilloso lote en venta, hermosa y...             Otro
# 1       Excelente local esquinero\n\nCon doble vitrina...             Otro
# 2       BODEGA EN BUEN ESTADO, SE ENCUENTRA UBICADA EN...             Otro
# 3       Vendo consultorio o oficina en edifico exclusi...          Oficina
# 4       En el momento de invertir en la compra de un i...      Apartamento
# ...                                                   ...              ...
# 999995  Jairo Ochoa Propiedad Raz ofrece para arrendam...  Local comercial
# 999996  Local para arriendo en el sector de la candela...  Local comercial
# 999997  LOCAL CALI TEQUENDAMA ALQUILER 400 m consta de...  Local comercial
# 999998  Arrienda Local Comercial de 254 M2. Ubicado en...  Local comercial
# 999999  Hermoso local duplex ubicado en el sector de a...  Local comercial
#
#        operation_type
# 0               Venta
# 1            Arriendo
# 2               Venta
# 3               Venta
# 4               Venta
# ...               ...
# 999995       Arriendo
# 999996       Arriendo
# 999997       Arriendo
# 999998       Arriendo
# 999999       Arriendo
#
# [1000000 rows x 25 columns]

# %%
df=df[df['l3']=='Bogotá D.C']

# %%
df=df.drop(columns=['l1', 'l2', 'l3'])

# %% [markdown]
# - Let´s check the currencies in which prices are reported to have consistency in porpeties prices

# %%
df.groupby('currency').agg({'id':'count'})
# Out:
#               id
# currency
# ARS            2
# COP       166941
# USD            4

# %%
df=df[df['currency']=='COP']

# %%
df
# Out:
#                               id    ad_type  start_date    end_date  \
# 1       exe9suxTarpGHR3XC7E5DQ==  Propiedad  2020-10-10  2020-10-30
# 189     6dVpYVaQbKbsG52zeifVZg==  Propiedad  2020-10-10  2020-11-12
# 190     sCNiDi252cmfBpOM9yeu1A==  Propiedad  2020-10-10  2020-11-13
# 191     z9uvWccPYAiKGp/KPXSqKQ==  Propiedad  2020-10-10  2021-07-01
# 192     ouliuIq3I6hNLU6T+Z+B0A==  Propiedad  2020-10-10  2020-11-12
# ...                          ...        ...         ...         ...
# 999985  kv5OAhtSoqnU+7uTtV1W+g==  Propiedad  2020-07-23  2020-08-01
# 999986  K4NSO+KjpX1jBHNwiUTlqA==  Propiedad  2020-07-23  2020-08-01
# 999987  ZARXoLFNyoYE4EIiSblC9g==  Propiedad  2020-07-23  2020-08-01
# 999996  VEkggjq5UPdxX5osneJGHQ==  Propiedad  2020-07-23  2021-08-09
# 999998  /qBt6Y8IqDeiKi3DC6XBLw==  Propiedad  2020-07-23  2021-03-16
#
#         created_on       lat        lon                  l4              l5  \
# 1       2020-10-10  4.592129 -74.123863            Zona Sur  Antonio Nariño
# 189     2020-10-10  4.704000 -74.047000          Zona Norte         Usaquén
# 190     2020-10-10  4.685000 -74.031000          Zona Norte         Usaquén
# 191     2020-10-10  4.691062 -74.038856          Zona Norte         Usaquén
# 192     2020-10-10  4.699000 -74.054000          Zona Norte         Usaquén
# ...            ...       ...        ...                 ...             ...
# 999985  2020-07-23  4.666000 -74.054000      Zona Chapinero       Chapinero
# 999986  2020-07-23       NaN        NaN  Zona Noroccidental            Suba
# 999987  2020-07-23  4.741000 -74.046000          Zona Norte         Usaquén
# 999996  2020-07-23  4.600097 -74.075562         Zona Centro   La Candelaria
# 999998  2020-07-23       NaN        NaN  Zona Noroccidental            Suba
#
#                      l6  ...  bathrooms  surface_total  surface_covered  \
# 1                   NaN  ...        NaN            NaN              NaN
# 189                 NaN  ...        NaN          500.0            400.0
# 190                 NaN  ...        NaN            NaN            210.0
# 191           Santa Ana  ...        NaN            NaN              NaN
# 192                 NaN  ...        NaN            NaN             43.0
# ...                 ...  ...        ...            ...              ...
# 999985        El Retiro  ...        1.0            NaN             24.0
# 999986         Salitre   ...        1.0           30.0             28.0
# 999987              NaN  ...        1.0           62.0             62.0
# 999996              NaN  ...        2.0            NaN              NaN
# 999998  Prado Veraniego  ...        3.0          102.0            254.0
#
#               price  currency  price_period  \
# 1        11000000.0       COP           NaN
# 189      12000000.0       COP           NaN
# 190       6200000.0       COP           NaN
# 191       7500000.0       COP           NaN
# 192     450000000.0       COP           NaN
# ...             ...       ...           ...
# 999985  650000000.0       COP           NaN
# 999986    3000000.0       COP           NaN
# 999987    2100000.0       COP           NaN
# 999996    2800000.0       COP           NaN
# 999998   10000000.0       COP           NaN
#
#                                                     title  \
# 1                Local comercial esquinero - Centro Mayor
# 189     Casa En Arriendo En Bogota Santa Brbara Cod. A...
# 190     Casa En Arriendo En Bogota Santa Ana Oriental ...
# 191                 OFICINA EN ARRIENDO, BOGOTA-SANTA ANA
# 192     Oficina En Venta En Bogota Santa Barbara Occid...
# ...                                                   ...
# 999985   Local En Venta En Bogota El Retiro Cod. VINH2705
# 999986  Local En Arriendo En Bogota Salitre Cod. ARYG1...
# 999987  Local En Arriendo En Bogota Calle 161 # 21 - 3...
# 999996            LOCAL EN ARRIENDO, BOGOTA-LA CANDELARIA
# 999998  Local En Arriendo En Bogota Prado Veraniego Co...
#
#                                               description    property_type  \
# 1       Excelente local esquinero\n\nCon doble vitrina...             Otro
# 189     CASA EXCELENTE UBICACION CERCA A UNICENTROUSO ...             Casa
# 190     INF: FLOR JIMENEZ 64154776748 SUPER EXCLUSIVO ...             Casa
# 191     Edificio inteligente, excelente seguridad,  ár...          Oficina
# 192     PADS te trae oficina para la venta modular y a...          Oficina
# ...                                                   ...              ...
# 999985  Local  remodelado, ubicado en  Centro comercia...  Local comercial
# 999986  EXCELENTE LOCAL COMERCIAL MUY BIEN UBICADO SOB...  Local comercial
# 999987  LOCAL SOBRE VIA PRINCIPAL, CON SALIDA PARA CUA...  Local comercial
# 999996  Local para arriendo en el sector de la candela...  Local comercial
# 999998  Arrienda Local Comercial de 254 M2. Ubicado en...  Local comercial
#
#        operation_type
# 1            Arriendo
# 189          Arriendo
# 190          Arriendo
# 191          Arriendo
# 192             Venta
# ...               ...
# 999985          Venta
# 999986       Arriendo
# 999987       Arriendo
# 999996       Arriendo
# 999998       Arriendo
#
# [166941 rows x 22 columns]

# %% [markdown]
# -What can we do with time data?

# %%
df['start_date']=pd.to_datetime(df['start_date'])
df['end_date']=pd.to_datetime(df['end_date'],errors='coerce')

# %%
date_variables=['start_date','end_date']
for i in date_variables:
    df[str(i)+'_year']=df[i].dt.year.astype(str)
    df[str(i)+'_month']=df[i].dt.month.astype(str)

# %%
df.columns
# Out:
# Index(['id', 'ad_type', 'start_date', 'end_date', 'created_on', 'lat', 'lon',
#        'l4', 'l5', 'l6', 'rooms', 'bedrooms', 'bathrooms', 'surface_total',
#        'surface_covered', 'price', 'currency', 'price_period', 'title',
#        'description', 'property_type', 'operation_type', 'start_date_year',
#        'start_date_month', 'end_date_year', 'end_date_month'],
#       dtype='object')

# %%
df=df.drop(columns=[ 'ad_type', 'start_date', 'end_date', 'created_on'])

# %% [markdown]
# - Our data is missing information that is realy important to predict the price of a property. Let´s try extract this information from the ad description

# %%
descriptions=df['description'].to_list()

# %%
elevator=[]
for i in tqdm(descriptions):
    try:
        if ('ascensor' in i) | ('Ascensor' in i) | ('ASCENSOR' in i) | ('ELEVADOR' in i) | ('Elevador' in i) | ('elevador' in i):
            elevator.append(1)
        else:
            elevator.append(0)
    except:
        elevator.append(0)
# Out:
# 100%|██████████| 166941/166941 [00:00<00:00, 422153.37it/s]

# %%
df['elevator']=elevator

# %%
df['elevator'] = df['elevator'].replace(0,np.nan)

# %%
df.groupby('elevator').agg({'id':'count'})
# Out:
#              id
# elevator
# 1.0       30554

# %% [markdown]
# - Can you think of a way to extract the number of garajes of a property from the description?

# %%
df=df.drop(columns=['title', 'description','currency','price_period'])

# %% [markdown]
# - Know we are going to save non continuos variables as catageorical data

# %%
df.columns
# Out:
# Index(['id', 'lat', 'lon', 'l4', 'l5', 'l6', 'rooms', 'bedrooms', 'bathrooms',
#        'surface_total', 'surface_covered', 'price', 'property_type',
#        'operation_type', 'start_date_year', 'start_date_month',
#        'end_date_year', 'end_date_month', 'elevator'],
#       dtype='object')

# %%
dummies= pd.get_dummies(df[[ 'l4', 'l5', 'l6','property_type', 'operation_type', 'start_date_year',
       'start_date_month', 'end_date_year', 'end_date_month']])

# %%
dummies
# Out:
#         l4_Zona Centro  l4_Zona Chapinero  l4_Zona Noroccidental  \
# 1                    0                  0                      0
# 189                  0                  0                      0
# 190                  0                  0                      0
# 191                  0                  0                      0
# 192                  0                  0                      0
# ...                ...                ...                    ...
# 999985               0                  1                      0
# 999986               0                  0                      1
# 999987               0                  0                      0
# 999996               1                  0                      0
# 999998               0                  0                      1
#
#         l4_Zona Norte  l4_Zona Occidental  l4_Zona Sur  l4_Zona Suroccidental  \
# 1                   0                   0            1                      0
# 189                 1                   0            0                      0
# 190                 1                   0            0                      0
# 191                 1                   0            0                      0
# 192                 1                   0            0                      0
# ...               ...                 ...          ...                    ...
# 999985              0                   0            0                      0
# 999986              0                   0            0                      0
# 999987              1                   0            0                      0
# 999996              0                   0            0                      0
# 999998              0                   0            0                      0
#
#         l5_Antonio Nariño  l5_Barrios Unidos  l5_Bosa  ...  \
# 1                       1                  0        0  ...
# 189                     0                  0        0  ...
# 190                     0                  0        0  ...
# 191                     0                  0        0  ...
# 192                     0                  0        0  ...
# ...                   ...                ...      ...  ...
# 999985                  0                  0        0  ...
# 999986                  0                  0        0  ...
# 999987                  0                  0        0  ...
# 999996                  0                  0        0  ...
# 999998                  0                  0        0  ...
#
#         end_date_month_12.0  end_date_month_2.0  end_date_month_3.0  \
# 1                         0                   0                   0
# 189                       0                   0                   0
# 190                       0                   0                   0
# 191                       0                   0                   0
# 192                       0                   0                   0
# ...                     ...                 ...                 ...
# 999985                    0                   0                   0
# 999986                    0                   0                   0
# 999987                    0                   0                   0
# 999996                    0                   0                   0
# 999998                    0                   0                   1
#
#         end_date_month_4.0  end_date_month_5.0  end_date_month_6.0  \
# 1                        0                   0                   0
# 189                      0                   0                   0
# 190                      0                   0                   0
# 191                      0                   0                   0
# 192                      0                   0                   0
# ...                    ...                 ...                 ...
# 999985                   0                   0                   0
# 999986                   0                   0                   0
# 999987                   0                   0                   0
# 999996                   0                   0                   0
# 999998                   0                   0                   0
#
#         end_date_month_7.0  end_date_month_8.0  end_date_month_9.0  \
# 1                        0                   0                   0
# 189                      0                   0                   0
# 190                      0                   0                   0
# 191                      1                   0                   0
# 192                      0                   0                   0
# ...                    ...                 ...                 ...
# 999985                   0                   1                   0
# 999986                   0                   1                   0
# 999987                   0                   1                   0
# 999996                   0                   1                   0
# 999998                   0                   0                   0
#
#         end_date_month_nan
# 1                        0
# 189                      0
# 190                      0
# 191                      0
# 192                      0
# ...                    ...
# 999985                   0
# 999986                   0
# 999987                   0
# 999996                   0
# 999998                   0
#
# [166941 rows x 231 columns]

# %%
df=df.drop(columns=[ 'l4', 'l5', 'l6','property_type', 'operation_type', 'start_date_year',
       'start_date_month', 'end_date_year', 'end_date_month','id'])

# %%
data = pd.concat([df, dummies], axis=1)

# %%
data
# Out:
#              lat        lon  rooms  bedrooms  bathrooms  surface_total  \
# 1       4.592129 -74.123863    NaN       NaN        NaN            NaN
# 189     4.704000 -74.047000    NaN       NaN        NaN          500.0
# 190     4.685000 -74.031000    4.0       4.0        NaN            NaN
# 191     4.691062 -74.038856    NaN       0.0        NaN            NaN
# 192     4.699000 -74.054000    NaN       NaN        NaN            NaN
# ...          ...        ...    ...       ...        ...            ...
# 999985  4.666000 -74.054000    NaN       NaN        1.0            NaN
# 999986       NaN        NaN    NaN       NaN        1.0           30.0
# 999987  4.741000 -74.046000    NaN       NaN        1.0           62.0
# 999996  4.600097 -74.075562    NaN       0.0        2.0            NaN
# 999998       NaN        NaN    NaN       NaN        3.0          102.0
#
#         surface_covered        price  elevator  l4_Zona Centro  ...  \
# 1                   NaN   11000000.0       NaN               0  ...
# 189               400.0   12000000.0       NaN               0  ...
# 190               210.0    6200000.0       NaN               0  ...
# 191                 NaN    7500000.0       NaN               0  ...
# 192                43.0  450000000.0       NaN               0  ...
# ...                 ...          ...       ...             ...  ...
# 999985             24.0  650000000.0       NaN               0  ...
# 999986             28.0    3000000.0       NaN               0  ...
# 999987             62.0    2100000.0       NaN               0  ...
# 999996              NaN    2800000.0       NaN               1  ...
# 999998            254.0   10000000.0       NaN               0  ...
#
#         end_date_month_12.0  end_date_month_2.0  end_date_month_3.0  \
# 1                         0                   0                   0
# 189                       0                   0                   0
# 190                       0                   0                   0
# 191                       0                   0                   0
# 192                       0                   0                   0
# ...                     ...                 ...                 ...
# 999985                    0                   0                   0
# 999986                    0                   0                   0
# 999987                    0                   0                   0
# 999996                    0                   0                   0
# 999998                    0                   0                   1
#
#         end_date_month_4.0  end_date_month_5.0  end_date_month_6.0  \
# 1                        0                   0                   0
# 189                      0                   0                   0
# 190                      0                   0                   0
# 191                      0                   0                   0
# 192                      0                   0                   0
# ...                    ...                 ...                 ...
# 999985                   0                   0                   0
# 999986                   0                   0                   0
# 999987                   0                   0                   0
# 999996                   0                   0                   0
# 999998                   0                   0                   0
#
#         end_date_month_7.0  end_date_month_8.0  end_date_month_9.0  \
# 1                        0                   0                   0
# 189                      0                   0                   0
# 190                      0                   0                   0
# 191                      1                   0                   0
# 192                      0                   0                   0
# ...                    ...                 ...                 ...
# 999985                   0                   1                   0
# 999986                   0                   1                   0
# 999987                   0                   1                   0
# 999996                   0                   1                   0
# 999998                   0                   0                   0
#
#         end_date_month_nan
# 1                        0
# 189                      0
# 190                      0
# 191                      0
# 192                      0
# ...                    ...
# 999985                   0
# 999986                   0
# 999987                   0
# 999996                   0
# 999998                   0
#
# [166941 rows x 240 columns]

# %% [markdown]
# ## **Missing values and data imputation**

# %%
data.isnull().sum()[:12]
# Out:
# lat                       12392
# lon                       12392
# rooms                    121931
# bedrooms                  74204
# bathrooms                 39723
# surface_total            156451
# surface_covered          144742
# price                         0
# elevator                 136387
# l4_Zona Centro                0
# l4_Zona Chapinero             0
# l4_Zona Noroccidental         0
# dtype: int64

# %%
data=data.drop(columns=['rooms'])

# %% [markdown]
# - As we can see, our data set has a lot of missing values. Deleting all missing values might not be the best strategy because we will be droping a lot of valuable information. For this reason, it could be usefull to use imputation methods to avoid loosing data. Take into acount:
#   1. If you are developing a Machine Learning project, dont impute the train data and the test data at once. If you do this your train data would have information about the test data distribution so your out of sample  error would not be a good measurment of your model acurracy
#   2. Dont impute your dependant variable with your features. If you do this, your data would have information about the variable its trying to predict so your prediction error wont be a good measurment of yout model acurracy

# %% [markdown]
# **"Manual" imputing**

# %% [markdown]
# - Example: In Colombia, every property with more that 5 storeys must have an elevator. Having this information, if we had a variable in our data set that gave us information about the ammount of floors of the building in which a give property is located, we could impute the elevator variable as follows:

# %%
for i in data.index:
    if (data['number_of_floors'][i]>5):
        data['elevator']=1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'number_of_floors'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-c1cdd9856696> in <module>
#       1 for i in data.index:
# ----> 2     if (data['number_of_floors'][i]>5):
#       3         data['elevator']=1
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'number_of_floors'

# %% [markdown]
# **simple imputation methods**

# %% [markdown]
# - Another way you could impute missing values of a given variable is by replacing the missing values with the mean or the median of this variable.

# %%
data1=data[['bedrooms','surface_total']]

# %%
a=data1['bedrooms'].mean()

# %%
data1['bedrooms'] = data1['bedrooms'].replace(np.nan,a)
# Out:
# <ipython-input-237-5d5a0fe02be6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['bedrooms'] = data1['bedrooms'].replace(np.nan,a)

# %%
data1['surface_total'] = data1['surface_total'].replace(np.nan,data1['surface_total'].median())
# Out:
# <ipython-input-239-717274307cf2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['surface_total'] = data1['surface_total'].replace(np.nan,data1['surface_total'].median())

# %%
data1.isnull().sum()
# Out:
# bedrooms         0
# surface_total    0
# dtype: int64

# %% [markdown]
# **Iterative imputer**

# %%
X=data.drop(columns=['price'])

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
imputer = IterativeImputer()

imputer.fit(X)

new_X = imputer.transform(X)
# Out:
# C:\Users\57320\Anaconda3\lib\site-packages\sklearn\impute\_iterative.py:669: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn("[IterativeImputer] Early stopping criterion not"

# %% [markdown]
# - Other nice imputations methods you could check out are MICE (Multiple Imputation with Chained Equations) and KNN imputation

# %%
columnas=data.columns

# %%
columnas
# Out:
# Index(['lat', 'lon', 'bedrooms', 'bathrooms', 'surface_total',
#        'surface_covered', 'price', 'elevator', 'l4_Zona Centro',
#        'l4_Zona Chapinero',
#        ...
#        'end_date_month_12.0', 'end_date_month_2.0', 'end_date_month_3.0',
#        'end_date_month_4.0', 'end_date_month_5.0', 'end_date_month_6.0',
#        'end_date_month_7.0', 'end_date_month_8.0', 'end_date_month_9.0',
#        'end_date_month_nan'],
#       dtype='object', length=239)

# %%
pd.DataFrame(new_X,columns=columnas)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1653                 blocks = [
# -> 1654                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1655                 ]
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3052
# -> 3053     return klass(values, ndim=ndim, placement=placement)
#    3054
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     123         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
# --> 124             raise ValueError(
#     125                 f"Wrong number of items passed {len(self.values)}, "
#
# ValueError: Wrong number of items passed 238, placement implies 239
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-246-d6a0e5d36ce2> in <module>
# ----> 1 pd.DataFrame(new_X,columns=columnas)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     462                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     463             else:
# --> 464                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     465
#     466         # For data is list-like, or Iterable (will consume into list)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     208         block_values = [values]
#     209
# --> 210     return create_block_manager_from_blocks(block_values, [columns, index])
#     211
#     212
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1662         blocks = [getattr(b, "values", b) for b in blocks]
#    1663         tot_items = sum(b.shape[0] for b in blocks)
# -> 1664         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1665
#    1666
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in construction_error(tot_items, block_shape, axes, e)
#    1692     if block_shape[0] == 0:
#    1693         raise ValueError("Empty data passed with indices specified.")
# -> 1694     raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#    1695
#    1696
#
# ValueError: Shape of passed values is (166941, 238), indices imply (166941, 239)
